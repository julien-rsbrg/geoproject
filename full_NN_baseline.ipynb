# %%
# %load_ext autoreload
# %autoreload 2

# %%
# data handling
import geopandas as gpd
import pandas as pd
import numpy as np
import utils

# data analysis
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import cross_val_score

from sklearn.metrics import accuracy_score, f1_score



import matplotlib.pyplot as plt
import tensorflow as tf
import keras
import pathlib
import os


#################### SET GPU ####################
print("tf.__version__:", tf.__version__)

physical_devices = tf.config.list_physical_devices("GPU")
print("Num GPUs Available: ", len(physical_devices))
# print(device_lib.list_local_devices())
tf.config.experimental.set_memory_growth(physical_devices[0], True)

DTYPE = 'float32'
tf.keras.backend.set_floatx(DTYPE)

AUTOTUNE = tf.data.AUTOTUNE


#################### CONFIG ####################
import yaml
from yaml.loader import SafeLoader


with open('CNN_config.yaml') as f:
    config = yaml.load(f, Loader=SafeLoader)

print("CNN_config:\n",config)
# Out:
# tf.__version__: 2.10.1
# Num GPUs Available:  1
# CNN_config:
#  {'BUFFER_SIZE': 100000, 'BATCH_SIZE': 32768}

# %%
change_type_map = {'Demolition': 0, 'Road': 1, 'Residential': 2, 'Commercial': 3, 'Industrial': 4,
                   'Mega Projects': 5}

# Read csvs
print("--- read .csv files ---")
train_df = gpd.read_file('train.geojson', index_col=0)

test_df = gpd.read_file('test.geojson', index_col=0)
# Out:
# --- read .csv files ---

# %%
print("--- Feature engineering ---")

def get_features_terrain(df):
    dic_features = {"names":[],"features":[]}

    # geometry features
    perimeter = np.asarray(df['geometry'].length)
    perimeter = np.expand_dims(perimeter, axis=-1)
    dic_features["features"].append(perimeter)
    dic_features["names"].append("perimeter")

    area_values = np.asarray(df['geometry'].area)
    area_values = np.expand_dims(area_values, axis=-1)
    dic_features["features"].append(area_values)
    dic_features["names"].append("area_values")

    def length_ratio(exte):
        x, y = exte.xy
        lengths = [
            np.sqrt((x[i] - x[i + 1]) ** 2 + (y[i] - y[i + 1]) ** 2) for i in range(4)
        ]
        return np.min(lengths) / np.max(lengths)


    ratios = np.asarray(df["geometry"].exterior.apply(length_ratio))
    ratios = np.expand_dims(ratios, axis=-1)
    dic_features["features"].append(ratios)
    dic_features["names"].append("ratios")
    
    # geography features
    le_urban_type = LabelEncoder()
    urban_type = np.asarray(df["urban_type"])
    le_urban_type.fit(urban_type)
    # print("possible urban_type list :", list(le_urban_type.classes_))
    urban_type = le_urban_type.transform(urban_type)
    urban_type = np.expand_dims(urban_type, axis=-1)
    dic_features["features"].append(urban_type)
    dic_features["names"].append("urban_type")


    res = np.concatenate(dic_features["features"], axis=-1)

    return res,dic_features

    

def get_features_sequence(df):
    dic_features = {"names":[],"features":[]}

    # dates/images features
    def get_sorted_date_diff_with_indices(df):
        dates_to_add = []
        for i in range(5):
            date = df[f'date{i}'].apply(lambda x: int(str(x)[-4:]) if x is not None else 0)
            date = np.asarray(date)
            date = np.expand_dims(date,axis=-1)
            dates_to_add.append(date)

        dates = np.concatenate(dates_to_add,axis=-1)

        indices_dates = np.argsort(dates,axis=-1)
        dates = np.array([dates[i,indices_dates[i,:]] for i in range(dates.shape[0])])

        date_diff = dates - dates[:,-1:]@np.ones((1,5),dtype=int)
        return date_diff, indices_dates

    date_diff,indices_dates=get_sorted_date_diff_with_indices(df)
    # dic_features["features"].append(date_diff)
    # dic_features["names"]+=[f"new_date_diff{i}" for i in range(5)]

    # colors
    trad_colors = {"red":0,"blue":1,"green":2}
    def get_mean_std(df):
        colors = list(trad_colors.keys())
        res = np.zeros((df.shape[0],5,3,2))
        for i in range(1,6):
            for j_color,color in enumerate(colors):
                res[:,i-1,j_color,0] = np.asarray(df[f"img_{color}_mean_date{i}"])
                res[:,i-1,j_color,0] = np.nan_to_num(res[:,i-1,j_color,0], nan=np.nanmean(res[:,i-1,j_color,0]))
                res[:,i-1,j_color,1] = np.asarray(df[f"img_{color}_std_date{i}"])
                res[:,i-1,j_color,1] = np.nan_to_num(res[:,i-1,j_color,1], nan=np.nanmean(res[:,i-1,j_color,1]))
        return res

    color_mean_std = get_mean_std(df)
    color_mean_std = np.array([color_mean_std[i,indices_dates[i,:],:,:] for i in range(color_mean_std.shape[0])])
    color_mean_std = np.concatenate([color_mean_std[:,:,:,i] for i in range(color_mean_std.shape[-1])],axis=-1)

    dic_features["features"].append(color_mean_std)
    dic_features["names"]+=[f"color_mean_{i}" for i in range(3)]
    dic_features["names"]+=[f"color_std_{i}" for i in range(3)]


    # change statuses
    le_change_status = LabelEncoder()
    change_statuses = np.zeros((df.shape[0],5),dtype=int)
    for i in range(5):
        change_status_datei = np.asarray(df[f"change_status_date{i}"])
        le_change_status.fit(change_status_datei)
        change_status_datei = le_change_status.transform(change_status_datei)
        change_statuses[:,i]= change_status_datei
    # print("le_change_status.classes_",le_change_status.classes_)
    # print("le_change_status.transform(le_change_status.classes_)",le_change_status.transform(le_change_status.classes_))

    change_statuses =  np.array([change_statuses[i,indices_dates[i,:]] for i in range(change_statuses.shape[0])])
    change_statuses = np.expand_dims(change_statuses,axis=-1)
    dic_features["features"].append(change_statuses)
    dic_features["names"]+=["change_statuses"]


    # final concatenation
    res = np.concatenate(dic_features["features"], axis=-1)

    return res,dic_features

def get_features_for_full_NN(df):
    features_terrain,dic_features_terrain = get_features_terrain(df)
    features_sequence,dic_features_sequence = get_features_sequence(df)

    dic_features = {"terrain":dic_features_terrain, "sequence":dic_features_sequence}

    return features_terrain,features_sequence,dic_features

    
# train_df_without_na,_,train_indices,train_dummy_values = handle_na_in_df(train_df)
train_terrain_x,train_sequence_x,dic_features= get_features_for_full_NN(train_df)
print("train:")
for k in dic_features.keys():
    print(k)
    utils.display_features(dic_features[k])
    
train_y = train_df['change_type'].apply(lambda x: change_type_map[x])

test_terrain_x,test_sequence_x,dic_features_test= get_features_for_full_NN(test_df)

print("test:")
for k in dic_features_test.keys():
    print(k)
    utils.display_features(dic_features_test[k])
# Out:
# --- Feature engineering ---
# C:\Users\jtros\AppData\Local\Temp\ipykernel_17932\2647003806.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'length' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   perimeter = np.asarray(df['geometry'].length)
# C:\Users\jtros\AppData\Local\Temp\ipykernel_17932\2647003806.py:12: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   area_values = np.asarray(df['geometry'].area)
# train:
# terrain
# ['perimeter'] (296146, 1)
# ['area_values'] (296146, 1)
# ['ratios'] (296146, 1)
# ['urban_type'] (296146, 1)
# sequence
# ['color_mean_0', 'color_mean_1', 'color_mean_2', 'color_std_0', 'color_std_1', 'color_std_2'] (296146, 5, 6)
# ['change_statuses'] (296146, 5, 1)
# C:\Users\jtros\AppData\Local\Temp\ipykernel_17932\2647003806.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'length' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   perimeter = np.asarray(df['geometry'].length)
# C:\Users\jtros\AppData\Local\Temp\ipykernel_17932\2647003806.py:12: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   area_values = np.asarray(df['geometry'].area)
# test:
# terrain
# ['perimeter'] (120526, 1)
# ['area_values'] (120526, 1)
# ['ratios'] (120526, 1)
# ['urban_type'] (120526, 1)
# sequence
# ['color_mean_0', 'color_mean_1', 'color_mean_2', 'color_std_0', 'color_std_1', 'color_std_2'] (120526, 5, 6)
# ['change_statuses'] (120526, 5, 1)

# %% [markdown]
# #### optimize in Tensorflow Dataset

# %%
def split_train_val(data,split_ratio=0.1):
    val_size = int(split_ratio*data.shape[0])
    np.random.seed(42)
    shuffle_indices = np.arange(0,data.shape[0])
    np.random.shuffle(shuffle_indices)
    data_shuffled = data[shuffle_indices]

    val_data = data_shuffled[:val_size]
    train_data = data_shuffled[val_size:]
    return train_data,val_data

new_train_terrain_x,new_val_terrain_x = split_train_val(train_terrain_x)
new_train_sequence_x, new_val_sequence_x = split_train_val(train_sequence_x)
new_train_y,new_val_y = split_train_val(train_y)

print("new_train_terrain_x shape",new_train_terrain_x.shape)
print("new_val_terrain_x shape",new_val_terrain_x.shape)
print("new_train_sequence_x shape",new_train_sequence_x.shape)
print("new_val_sequence_x shape",new_val_sequence_x.shape)
print("new_train_y shape",new_train_y.shape)
print("new_val_y shape",new_val_y.shape)
# Out:
# new_train_terrain_x shape (266532, 4)
# new_val_terrain_x shape (29614, 4)
# new_train_sequence_x shape (266532, 5, 7)
# new_val_sequence_x shape (29614, 5, 7)
# new_train_y shape (266532,)
# new_val_y shape (29614,)
# C:\Users\jtros\AppData\Local\Temp\ipykernel_17932\1833676520.py:8: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   val_data = data_shuffled[:val_size]
# C:\Users\jtros\AppData\Local\Temp\ipykernel_17932\1833676520.py:9: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   train_data = data_shuffled[val_size:]

# %%
train_dataset_x = tf.data.Dataset.from_tensor_slices((new_train_terrain_x,new_train_sequence_x))
train_dataset_y = tf.data.Dataset.from_tensor_slices(np.expand_dims(new_train_y,axis=-1))
train_dataset = tf.data.Dataset.zip((train_dataset_x, train_dataset_y))

val_dataset_x = tf.data.Dataset.from_tensor_slices((new_val_terrain_x,new_val_sequence_x))
val_dataset_y = tf.data.Dataset.from_tensor_slices(np.expand_dims(new_val_y,axis=-1))
val_dataset = tf.data.Dataset.zip((val_dataset_x, val_dataset_y))


def configure_for_performance(ds, batch_size):
    ds = ds.cache()
    ds = ds.shuffle(
        buffer_size=config["BUFFER_SIZE"], reshuffle_each_iteration=True)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds


train_dataset = configure_for_performance(train_dataset, config["BATCH_SIZE"])
val_dataset = configure_for_performance(val_dataset, config["BATCH_SIZE"])

for (batch_terrain_x,batch_sequence_x),batch_y in train_dataset.take(5):
    print("batch_x.shape,batch_sequence_x,batch_y.shape\n",batch_terrain_x.shape,batch_sequence_x.shape,batch_y.shape)
# Out:
# batch_x.shape,batch_sequence_x,batch_y.shape
#  (32768, 4) (32768, 5, 7) (32768, 1)
# batch_x.shape,batch_sequence_x,batch_y.shape
#  (32768, 4) (32768, 5, 7) (32768, 1)
# batch_x.shape,batch_sequence_x,batch_y.shape
#  (32768, 4) (32768, 5, 7) (32768, 1)
# batch_x.shape,batch_sequence_x,batch_y.shape
#  (32768, 4) (32768, 5, 7) (32768, 1)
# batch_x.shape,batch_sequence_x,batch_y.shape
#  (32768, 4) (32768, 5, 7) (32768, 1)

# %% [markdown]
# #### Create and train CNN

# %%
input_terrain_shape = train_terrain_x.shape[1:]
input_sequence_shape = train_sequence_x.shape[1:]

def get_CNN_model(input_shape):
        model_dense_32 = tf.keras.Sequential([
            tf.keras.layers.Conv1D(filters=256,kernel_size=3, activation='relu',kernel_initializer="HeNormal",padding="same",input_shape=input_shape),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Conv1D(256,3, padding="same",activation='relu',kernel_initializer="HeNormal"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Conv1D(128,3, padding="same",activation='relu',kernel_initializer="HeNormal"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Conv1D(128,3, padding="same",activation='relu',kernel_initializer="HeNormal"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Conv1D(64,3, padding="same",activation='relu',kernel_initializer="HeNormal"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Conv1D(64,3, padding="same",activation='relu',kernel_initializer="HeNormal"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Conv1D(32,3, padding="same",activation='relu',kernel_initializer="HeNormal"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(32, activation='relu',kernel_initializer="HeNormal"),
        ],name='model_dense_32')

        model_dense_16 = tf.keras.Sequential([
            model_dense_32,
            tf.keras.layers.Dense(16, activation='relu',kernel_initializer="HeNormal"),
        ],name="model_dense_16")

        CNN_model = tf.keras.Sequential([
            model_dense_16,
            tf.keras.layers.Dense(6, activation='softmax'),
        ])

        CNN_model.summary()
        return model_dense_32, model_dense_16,CNN_model


class FullNNModel(keras.Model):
    def __init__(self,input_terrain_shape,input_sequence_shape,**kwargs):
        super().__init__(**kwargs)
        self.CNN_model_cut_at_dense_32, _,_ = get_CNN_model(input_sequence_shape)
        self.terrain_model = tf.keras.Sequential([
            tf.keras.layers.Dense(256,activation="elu",kernel_initializer="HeNormal"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(128,activation="elu",kernel_initializer="HeNormal"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dropout(0.3),
            tf.keras.layers.Dense(128,activation="elu",kernel_initializer="HeNormal"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(64,activation="elu",kernel_initializer="HeNormal"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(64,activation="elu",kernel_initializer="HeNormal"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(32,activation="elu",kernel_initializer="HeNormal"),
            tf.keras.layers.BatchNormalization(),
        ],name='terrain_model')

        self.output_model = tf.keras.Sequential([
            tf.keras.layers.Dense(64,activation="elu",kernel_initializer="HeNormal"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(32,activation="elu",kernel_initializer="HeNormal"),
            tf.keras.layers.BatchNormalization(),
            tf.keras.layers.Dense(16,activation="elu",kernel_initializer="HeNormal"),
            tf.keras.layers.Dense(6,activation="softmax",kernel_initializer="GlorotNormal")
        ])


    def call(self,inputs):
        input_terrain, input_sequence = inputs
        hidden_terrain = self.terrain_model(input_terrain)
        hidden_sequences = self.CNN_model_cut_at_dense_32(input_sequence)
        concat = keras.layers.Concatenate()([hidden_terrain,hidden_sequences])
        main_output = self.output_model(concat)
        return main_output


full_NN_model = FullNNModel(input_terrain_shape,input_sequence_shape)

full_NN_model.compile(optimizer=tf.keras.optimizers.Adam(1e-4),
                loss=keras.losses.SparseCategoricalCrossentropy(),
                metrics=['sparse_categorical_accuracy'])
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model_dense_16 (Sequential)  (None, 16)               402768
#
#  dense_28 (Dense)            (None, 6)                 102
#
# =================================================================
# Total params: 402,870
# Trainable params: 401,014
# Non-trainable params: 1,856
# _________________________________________________________________

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(monitor="val_sparse_categorical_accuracy" ,patience=200,restore_best_weights=True)

history = full_NN_model.fit(train_dataset, epochs=10000, validation_data=val_dataset,callbacks=[early_stopping_cb])
# Out:
# Epoch 1/10000
# 9/9 [==============================] - 7s 474ms/step - loss: 2.3683 - sparse_categorical_accuracy: 0.1765 - val_loss: 14.4347 - val_sparse_categorical_accuracy: 0.0581
# Epoch 2/10000
# 9/9 [==============================] - 4s 442ms/step - loss: 2.2075 - sparse_categorical_accuracy: 0.1955 - val_loss: 9.2644 - val_sparse_categorical_accuracy: 0.1254
# Epoch 3/10000
# 9/9 [==============================] - 4s 447ms/step - loss: 2.0766 - sparse_categorical_accuracy: 0.2229 - val_loss: 6.3486 - val_sparse_categorical_accuracy: 0.2214
# Epoch 4/10000
# 9/9 [==============================] - 4s 420ms/step - loss: 1.9722 - sparse_categorical_accuracy: 0.2529 - val_loss: 4.4289 - val_sparse_categorical_accuracy: 0.2474
# Epoch 5/10000
# 9/9 [==============================] - 4s 426ms/step - loss: 1.8863 - sparse_categorical_accuracy: 0.2806 - val_loss: 3.3435 - val_sparse_categorical_accuracy: 0.2532
# Epoch 6/10000
# 9/9 [==============================] - 4s 450ms/step - loss: 1.8132 - sparse_categorical_accuracy: 0.3117 - val_loss: 2.7880 - val_sparse_categorical_accuracy: 0.2365
# Epoch 7/10000
# 9/9 [==============================] - 4s 438ms/step - loss: 1.7518 - sparse_categorical_accuracy: 0.3366 - val_loss: 2.4462 - val_sparse_categorical_accuracy: 0.2340
# Epoch 8/10000
# 9/9 [==============================] - 4s 437ms/step - loss: 1.7020 - sparse_categorical_accuracy: 0.3584 - val_loss: 2.2011 - val_sparse_categorical_accuracy: 0.2487
# Epoch 9/10000
# 9/9 [==============================] - 4s 461ms/step - loss: 1.6529 - sparse_categorical_accuracy: 0.3810 - val_loss: 1.9828 - val_sparse_categorical_accuracy: 0.2719
# Epoch 10/10000
# 9/9 [==============================] - 4s 441ms/step - loss: 1.6121 - sparse_categorical_accuracy: 0.4021 - val_loss: 1.8433 - val_sparse_categorical_accuracy: 0.2985
# Epoch 11/10000
# 9/9 [==============================] - 4s 448ms/step - loss: 1.5744 - sparse_categorical_accuracy: 0.4197 - val_loss: 1.7333 - val_sparse_categorical_accuracy: 0.3235
# Epoch 12/10000
# 9/9 [==============================] - 4s 431ms/step - loss: 1.5413 - sparse_categorical_accuracy: 0.4369 - val_loss: 1.6417 - val_sparse_categorical_accuracy: 0.3505
# Epoch 13/10000
# 9/9 [==============================] - 4s 464ms/step - loss: 1.5109 - sparse_categorical_accuracy: 0.4539 - val_loss: 1.5578 - val_sparse_categorical_accuracy: 0.3736
# Epoch 14/10000
# 9/9 [==============================] - 4s 443ms/step - loss: 1.4807 - sparse_categorical_accuracy: 0.4674 - val_loss: 1.5002 - val_sparse_categorical_accuracy: 0.3946
# Epoch 15/10000
# 9/9 [==============================] - 4s 447ms/step - loss: 1.4544 - sparse_categorical_accuracy: 0.4799 - val_loss: 1.4552 - val_sparse_categorical_accuracy: 0.4123
# Epoch 16/10000
# 9/9 [==============================] - 4s 438ms/step - loss: 1.4292 - sparse_categorical_accuracy: 0.4907 - val_loss: 1.4210 - val_sparse_categorical_accuracy: 0.4281
# Epoch 17/10000
# 9/9 [==============================] - 4s 463ms/step - loss: 1.4066 - sparse_categorical_accuracy: 0.4984 - val_loss: 1.3935 - val_sparse_categorical_accuracy: 0.4487
# Epoch 18/10000
# 9/9 [==============================] - 4s 474ms/step - loss: 1.3822 - sparse_categorical_accuracy: 0.5073 - val_loss: 1.3709 - val_sparse_categorical_accuracy: 0.4665
# Epoch 19/10000
# 9/9 [==============================] - 4s 430ms/step - loss: 1.3629 - sparse_categorical_accuracy: 0.5123 - val_loss: 1.3547 - val_sparse_categorical_accuracy: 0.4789
# Epoch 20/10000
# 9/9 [==============================] - 4s 431ms/step - loss: 1.3426 - sparse_categorical_accuracy: 0.5171 - val_loss: 1.3428 - val_sparse_categorical_accuracy: 0.4875
# Epoch 21/10000
# 9/9 [==============================] - 4s 446ms/step - loss: 1.3244 - sparse_categorical_accuracy: 0.5201 - val_loss: 1.3325 - val_sparse_categorical_accuracy: 0.4946
# Epoch 22/10000
# 9/9 [==============================] - 4s 445ms/step - loss: 1.3062 - sparse_categorical_accuracy: 0.5245 - val_loss: 1.3217 - val_sparse_categorical_accuracy: 0.5015
# Epoch 23/10000
# 9/9 [==============================] - 4s 433ms/step - loss: 1.2917 - sparse_categorical_accuracy: 0.5280 - val_loss: 1.3113 - val_sparse_categorical_accuracy: 0.5064
# Epoch 24/10000
# 9/9 [==============================] - 4s 457ms/step - loss: 1.2763 - sparse_categorical_accuracy: 0.5293 - val_loss: 1.2998 - val_sparse_categorical_accuracy: 0.5090
# Epoch 25/10000
# 9/9 [==============================] - 4s 465ms/step - loss: 1.2633 - sparse_categorical_accuracy: 0.5320 - val_loss: 1.2883 - val_sparse_categorical_accuracy: 0.5104
# Epoch 26/10000
# 9/9 [==============================] - 4s 453ms/step - loss: 1.2502 - sparse_categorical_accuracy: 0.5334 - val_loss: 1.2765 - val_sparse_categorical_accuracy: 0.5120
# Epoch 27/10000
# 9/9 [==============================] - 4s 454ms/step - loss: 1.2391 - sparse_categorical_accuracy: 0.5332 - val_loss: 1.2643 - val_sparse_categorical_accuracy: 0.5134
# Epoch 28/10000
# 9/9 [==============================] - 4s 459ms/step - loss: 1.2281 - sparse_categorical_accuracy: 0.5352 - val_loss: 1.2522 - val_sparse_categorical_accuracy: 0.5144
# Epoch 29/10000
# 9/9 [==============================] - 4s 442ms/step - loss: 1.2180 - sparse_categorical_accuracy: 0.5367 - val_loss: 1.2385 - val_sparse_categorical_accuracy: 0.5163
# Epoch 30/10000
# 9/9 [==============================] - 4s 457ms/step - loss: 1.2067 - sparse_categorical_accuracy: 0.5378 - val_loss: 1.2237 - val_sparse_categorical_accuracy: 0.5182
# Epoch 31/10000
# 9/9 [==============================] - 4s 457ms/step - loss: 1.1992 - sparse_categorical_accuracy: 0.5391 - val_loss: 1.2093 - val_sparse_categorical_accuracy: 0.5196
# Epoch 32/10000
# 9/9 [==============================] - 4s 408ms/step - loss: 1.1901 - sparse_categorical_accuracy: 0.5396 - val_loss: 1.1946 - val_sparse_categorical_accuracy: 0.5211
# Epoch 33/10000
# 9/9 [==============================] - 4s 446ms/step - loss: 1.1821 - sparse_categorical_accuracy: 0.5393 - val_loss: 1.1803 - val_sparse_categorical_accuracy: 0.5225
# Epoch 34/10000
# 9/9 [==============================] - 4s 458ms/step - loss: 1.1738 - sparse_categorical_accuracy: 0.5406 - val_loss: 1.1689 - val_sparse_categorical_accuracy: 0.5245
# Epoch 35/10000
# 9/9 [==============================] - 4s 473ms/step - loss: 1.1669 - sparse_categorical_accuracy: 0.5419 - val_loss: 1.1590 - val_sparse_categorical_accuracy: 0.5260
# Epoch 36/10000
# 9/9 [==============================] - 4s 461ms/step - loss: 1.1597 - sparse_categorical_accuracy: 0.5417 - val_loss: 1.1508 - val_sparse_categorical_accuracy: 0.5276
# Epoch 37/10000
# 9/9 [==============================] - 4s 420ms/step - loss: 1.1537 - sparse_categorical_accuracy: 0.5433 - val_loss: 1.1440 - val_sparse_categorical_accuracy: 0.5290
# Epoch 38/10000
# 9/9 [==============================] - 4s 465ms/step - loss: 1.1480 - sparse_categorical_accuracy: 0.5440 - val_loss: 1.1377 - val_sparse_categorical_accuracy: 0.5298
# Epoch 39/10000
# 9/9 [==============================] - 4s 446ms/step - loss: 1.1421 - sparse_categorical_accuracy: 0.5434 - val_loss: 1.1319 - val_sparse_categorical_accuracy: 0.5308
# Epoch 40/10000
# 9/9 [==============================] - 4s 440ms/step - loss: 1.1368 - sparse_categorical_accuracy: 0.5441 - val_loss: 1.1265 - val_sparse_categorical_accuracy: 0.5319
# Epoch 41/10000
# 9/9 [==============================] - 4s 450ms/step - loss: 1.1314 - sparse_categorical_accuracy: 0.5443 - val_loss: 1.1240 - val_sparse_categorical_accuracy: 0.5326
# Epoch 42/10000
# 9/9 [==============================] - 4s 443ms/step - loss: 1.1262 - sparse_categorical_accuracy: 0.5455 - val_loss: 1.1212 - val_sparse_categorical_accuracy: 0.5334
# Epoch 43/10000
# 9/9 [==============================] - 4s 442ms/step - loss: 1.1227 - sparse_categorical_accuracy: 0.5454 - val_loss: 1.1171 - val_sparse_categorical_accuracy: 0.5342
# Epoch 44/10000
# 9/9 [==============================] - 4s 449ms/step - loss: 1.1175 - sparse_categorical_accuracy: 0.5459 - val_loss: 1.1138 - val_sparse_categorical_accuracy: 0.5352
# Epoch 45/10000
# 9/9 [==============================] - 4s 436ms/step - loss: 1.1140 - sparse_categorical_accuracy: 0.5459 - val_loss: 1.1122 - val_sparse_categorical_accuracy: 0.5357
# Epoch 46/10000
# 9/9 [==============================] - 4s 444ms/step - loss: 1.1102 - sparse_categorical_accuracy: 0.5463 - val_loss: 1.1092 - val_sparse_categorical_accuracy: 0.5365
# Epoch 47/10000
# 9/9 [==============================] - 4s 439ms/step - loss: 1.1061 - sparse_categorical_accuracy: 0.5467 - val_loss: 1.1067 - val_sparse_categorical_accuracy: 0.5364
# Epoch 48/10000
# 9/9 [==============================] - 4s 436ms/step - loss: 1.1030 - sparse_categorical_accuracy: 0.5467 - val_loss: 1.1058 - val_sparse_categorical_accuracy: 0.5364
# Epoch 49/10000
# 9/9 [==============================] - 4s 426ms/step - loss: 1.0993 - sparse_categorical_accuracy: 0.5470 - val_loss: 1.1032 - val_sparse_categorical_accuracy: 0.5372
# Epoch 50/10000
# 9/9 [==============================] - 4s 450ms/step - loss: 1.0959 - sparse_categorical_accuracy: 0.5485 - val_loss: 1.0987 - val_sparse_categorical_accuracy: 0.5384
# Epoch 51/10000
# 9/9 [==============================] - 4s 463ms/step - loss: 1.0927 - sparse_categorical_accuracy: 0.5486 - val_loss: 1.0959 - val_sparse_categorical_accuracy: 0.5389
# Epoch 52/10000
# 9/9 [==============================] - 4s 473ms/step - loss: 1.0908 - sparse_categorical_accuracy: 0.5491 - val_loss: 1.0925 - val_sparse_categorical_accuracy: 0.5391
# Epoch 53/10000
# 9/9 [==============================] - 4s 469ms/step - loss: 1.0871 - sparse_categorical_accuracy: 0.5492 - val_loss: 1.0891 - val_sparse_categorical_accuracy: 0.5399
# Epoch 54/10000
# 9/9 [==============================] - 4s 464ms/step - loss: 1.0840 - sparse_categorical_accuracy: 0.5494 - val_loss: 1.0881 - val_sparse_categorical_accuracy: 0.5399
# Epoch 55/10000
# 9/9 [==============================] - 4s 436ms/step - loss: 1.0826 - sparse_categorical_accuracy: 0.5492 - val_loss: 1.0856 - val_sparse_categorical_accuracy: 0.5405
# Epoch 56/10000
# 9/9 [==============================] - 4s 451ms/step - loss: 1.0800 - sparse_categorical_accuracy: 0.5502 - val_loss: 1.0821 - val_sparse_categorical_accuracy: 0.5415
# Epoch 57/10000
# 9/9 [==============================] - 4s 420ms/step - loss: 1.0777 - sparse_categorical_accuracy: 0.5494 - val_loss: 1.0776 - val_sparse_categorical_accuracy: 0.5428
# Epoch 58/10000
# 9/9 [==============================] - 4s 467ms/step - loss: 1.0744 - sparse_categorical_accuracy: 0.5506 - val_loss: 1.0732 - val_sparse_categorical_accuracy: 0.5445
# Epoch 59/10000
# 9/9 [==============================] - 4s 429ms/step - loss: 1.0726 - sparse_categorical_accuracy: 0.5508 - val_loss: 1.0706 - val_sparse_categorical_accuracy: 0.5447
# Epoch 60/10000
# 9/9 [==============================] - 4s 426ms/step - loss: 1.0695 - sparse_categorical_accuracy: 0.5506 - val_loss: 1.0693 - val_sparse_categorical_accuracy: 0.5450
# Epoch 61/10000
# 9/9 [==============================] - 4s 435ms/step - loss: 1.0661 - sparse_categorical_accuracy: 0.5517 - val_loss: 1.0644 - val_sparse_categorical_accuracy: 0.5452
# Epoch 62/10000
# 9/9 [==============================] - 4s 441ms/step - loss: 1.0640 - sparse_categorical_accuracy: 0.5517 - val_loss: 1.0607 - val_sparse_categorical_accuracy: 0.5462
# Epoch 63/10000
# 9/9 [==============================] - 4s 457ms/step - loss: 1.0615 - sparse_categorical_accuracy: 0.5524 - val_loss: 1.0572 - val_sparse_categorical_accuracy: 0.5464
# Epoch 64/10000
# 9/9 [==============================] - 4s 465ms/step - loss: 1.0594 - sparse_categorical_accuracy: 0.5519 - val_loss: 1.0521 - val_sparse_categorical_accuracy: 0.5471
# Epoch 65/10000
# 9/9 [==============================] - 4s 453ms/step - loss: 1.0562 - sparse_categorical_accuracy: 0.5529 - val_loss: 1.0469 - val_sparse_categorical_accuracy: 0.5485
# Epoch 66/10000
# 9/9 [==============================] - 5s 481ms/step - loss: 1.0534 - sparse_categorical_accuracy: 0.5537 - val_loss: 1.0427 - val_sparse_categorical_accuracy: 0.5488
# Epoch 67/10000
# 9/9 [==============================] - 4s 474ms/step - loss: 1.0516 - sparse_categorical_accuracy: 0.5529 - val_loss: 1.0393 - val_sparse_categorical_accuracy: 0.5487
# Epoch 68/10000
# 9/9 [==============================] - 4s 432ms/step - loss: 1.0480 - sparse_categorical_accuracy: 0.5537 - val_loss: 1.0359 - val_sparse_categorical_accuracy: 0.5492
# Epoch 69/10000
# 9/9 [==============================] - 4s 468ms/step - loss: 1.0461 - sparse_categorical_accuracy: 0.5534 - val_loss: 1.0323 - val_sparse_categorical_accuracy: 0.5501
# Epoch 70/10000
# 9/9 [==============================] - 4s 472ms/step - loss: 1.0429 - sparse_categorical_accuracy: 0.5541 - val_loss: 1.0289 - val_sparse_categorical_accuracy: 0.5503
# Epoch 71/10000
# 9/9 [==============================] - 4s 431ms/step - loss: 1.0395 - sparse_categorical_accuracy: 0.5551 - val_loss: 1.0254 - val_sparse_categorical_accuracy: 0.5508
# Epoch 72/10000
# 9/9 [==============================] - 4s 455ms/step - loss: 1.0377 - sparse_categorical_accuracy: 0.5539 - val_loss: 1.0198 - val_sparse_categorical_accuracy: 0.5524
# Epoch 73/10000
# 9/9 [==============================] - 4s 438ms/step - loss: 1.0340 - sparse_categorical_accuracy: 0.5554 - val_loss: 1.0143 - val_sparse_categorical_accuracy: 0.5536
# Epoch 74/10000
# 9/9 [==============================] - 4s 468ms/step - loss: 1.0323 - sparse_categorical_accuracy: 0.5540 - val_loss: 1.0103 - val_sparse_categorical_accuracy: 0.5548
# Epoch 75/10000
# 9/9 [==============================] - 4s 423ms/step - loss: 1.0304 - sparse_categorical_accuracy: 0.5549 - val_loss: 1.0070 - val_sparse_categorical_accuracy: 0.5546
# Epoch 76/10000
# 9/9 [==============================] - 4s 443ms/step - loss: 1.0265 - sparse_categorical_accuracy: 0.5557 - val_loss: 1.0031 - val_sparse_categorical_accuracy: 0.5547
# Epoch 77/10000
# 9/9 [==============================] - 4s 452ms/step - loss: 1.0244 - sparse_categorical_accuracy: 0.5560 - val_loss: 1.0000 - val_sparse_categorical_accuracy: 0.5549
# Epoch 78/10000
# 9/9 [==============================] - 4s 450ms/step - loss: 1.0218 - sparse_categorical_accuracy: 0.5564 - val_loss: 0.9974 - val_sparse_categorical_accuracy: 0.5548
# Epoch 79/10000
# 9/9 [==============================] - 4s 467ms/step - loss: 1.0198 - sparse_categorical_accuracy: 0.5573 - val_loss: 0.9944 - val_sparse_categorical_accuracy: 0.5557
# Epoch 80/10000
# 9/9 [==============================] - 4s 462ms/step - loss: 1.0178 - sparse_categorical_accuracy: 0.5566 - val_loss: 0.9914 - val_sparse_categorical_accuracy: 0.5559
# Epoch 81/10000
# 9/9 [==============================] - 5s 498ms/step - loss: 1.0161 - sparse_categorical_accuracy: 0.5575 - val_loss: 0.9892 - val_sparse_categorical_accuracy: 0.5565
# Epoch 82/10000
# 9/9 [==============================] - 4s 437ms/step - loss: 1.0121 - sparse_categorical_accuracy: 0.5585 - val_loss: 0.9864 - val_sparse_categorical_accuracy: 0.5570
# Epoch 83/10000
# 9/9 [==============================] - 4s 444ms/step - loss: 1.0110 - sparse_categorical_accuracy: 0.5588 - val_loss: 0.9846 - val_sparse_categorical_accuracy: 0.5574
# Epoch 84/10000
# 9/9 [==============================] - 4s 446ms/step - loss: 1.0093 - sparse_categorical_accuracy: 0.5588 - val_loss: 0.9816 - val_sparse_categorical_accuracy: 0.5584
# Epoch 85/10000
# 9/9 [==============================] - 4s 445ms/step - loss: 1.0069 - sparse_categorical_accuracy: 0.5596 - val_loss: 0.9779 - val_sparse_categorical_accuracy: 0.5604
# Epoch 86/10000
# 9/9 [==============================] - 4s 434ms/step - loss: 1.0048 - sparse_categorical_accuracy: 0.5608 - val_loss: 0.9758 - val_sparse_categorical_accuracy: 0.5621
# Epoch 87/10000
# 9/9 [==============================] - 4s 456ms/step - loss: 1.0028 - sparse_categorical_accuracy: 0.5614 - val_loss: 0.9732 - val_sparse_categorical_accuracy: 0.5627
# Epoch 88/10000
# 9/9 [==============================] - 4s 431ms/step - loss: 1.0017 - sparse_categorical_accuracy: 0.5610 - val_loss: 0.9714 - val_sparse_categorical_accuracy: 0.5628
# Epoch 89/10000
# 9/9 [==============================] - 4s 438ms/step - loss: 0.9984 - sparse_categorical_accuracy: 0.5620 - val_loss: 0.9707 - val_sparse_categorical_accuracy: 0.5626
# Epoch 90/10000
# 9/9 [==============================] - 4s 442ms/step - loss: 0.9974 - sparse_categorical_accuracy: 0.5608 - val_loss: 0.9700 - val_sparse_categorical_accuracy: 0.5621
# Epoch 91/10000
# 9/9 [==============================] - 4s 448ms/step - loss: 0.9946 - sparse_categorical_accuracy: 0.5627 - val_loss: 0.9673 - val_sparse_categorical_accuracy: 0.5639
# Epoch 92/10000
# 9/9 [==============================] - 4s 448ms/step - loss: 0.9927 - sparse_categorical_accuracy: 0.5633 - val_loss: 0.9630 - val_sparse_categorical_accuracy: 0.5658
# Epoch 93/10000
# 9/9 [==============================] - 4s 432ms/step - loss: 0.9912 - sparse_categorical_accuracy: 0.5638 - val_loss: 0.9607 - val_sparse_categorical_accuracy: 0.5673
# Epoch 94/10000
# 9/9 [==============================] - 4s 433ms/step - loss: 0.9896 - sparse_categorical_accuracy: 0.5640 - val_loss: 0.9599 - val_sparse_categorical_accuracy: 0.5681
# Epoch 95/10000
# 9/9 [==============================] - 4s 429ms/step - loss: 0.9871 - sparse_categorical_accuracy: 0.5640 - val_loss: 0.9583 - val_sparse_categorical_accuracy: 0.5686
# Epoch 96/10000
# 9/9 [==============================] - 4s 428ms/step - loss: 0.9855 - sparse_categorical_accuracy: 0.5654 - val_loss: 0.9567 - val_sparse_categorical_accuracy: 0.5691
# Epoch 97/10000
# 9/9 [==============================] - 4s 430ms/step - loss: 0.9839 - sparse_categorical_accuracy: 0.5659 - val_loss: 0.9558 - val_sparse_categorical_accuracy: 0.5706
# Epoch 98/10000
# 9/9 [==============================] - 4s 437ms/step - loss: 0.9817 - sparse_categorical_accuracy: 0.5675 - val_loss: 0.9526 - val_sparse_categorical_accuracy: 0.5711
# Epoch 99/10000
# 9/9 [==============================] - 4s 438ms/step - loss: 0.9802 - sparse_categorical_accuracy: 0.5670 - val_loss: 0.9496 - val_sparse_categorical_accuracy: 0.5724
# Epoch 100/10000
# 9/9 [==============================] - 4s 441ms/step - loss: 0.9786 - sparse_categorical_accuracy: 0.5673 - val_loss: 0.9471 - val_sparse_categorical_accuracy: 0.5746
# Epoch 101/10000
# 9/9 [==============================] - 4s 409ms/step - loss: 0.9760 - sparse_categorical_accuracy: 0.5683 - val_loss: 0.9463 - val_sparse_categorical_accuracy: 0.5746
# Epoch 102/10000
# 9/9 [==============================] - 4s 456ms/step - loss: 0.9736 - sparse_categorical_accuracy: 0.5712 - val_loss: 0.9446 - val_sparse_categorical_accuracy: 0.5764
# Epoch 103/10000
# 9/9 [==============================] - 4s 454ms/step - loss: 0.9721 - sparse_categorical_accuracy: 0.5695 - val_loss: 0.9428 - val_sparse_categorical_accuracy: 0.5775
# Epoch 104/10000
# 9/9 [==============================] - 4s 446ms/step - loss: 0.9705 - sparse_categorical_accuracy: 0.5710 - val_loss: 0.9419 - val_sparse_categorical_accuracy: 0.5788
# Epoch 105/10000
# 9/9 [==============================] - 4s 429ms/step - loss: 0.9683 - sparse_categorical_accuracy: 0.5715 - val_loss: 0.9414 - val_sparse_categorical_accuracy: 0.5785
# Epoch 106/10000
# 9/9 [==============================] - 4s 439ms/step - loss: 0.9667 - sparse_categorical_accuracy: 0.5725 - val_loss: 0.9400 - val_sparse_categorical_accuracy: 0.5792
# Epoch 107/10000
# 9/9 [==============================] - 4s 425ms/step - loss: 0.9652 - sparse_categorical_accuracy: 0.5726 - val_loss: 0.9402 - val_sparse_categorical_accuracy: 0.5793
# Epoch 108/10000
# 9/9 [==============================] - 4s 421ms/step - loss: 0.9636 - sparse_categorical_accuracy: 0.5729 - val_loss: 0.9369 - val_sparse_categorical_accuracy: 0.5813
# Epoch 109/10000
# 9/9 [==============================] - 4s 419ms/step - loss: 0.9618 - sparse_categorical_accuracy: 0.5736 - val_loss: 0.9329 - val_sparse_categorical_accuracy: 0.5826
# Epoch 110/10000
# 9/9 [==============================] - 4s 430ms/step - loss: 0.9601 - sparse_categorical_accuracy: 0.5748 - val_loss: 0.9321 - val_sparse_categorical_accuracy: 0.5840
# Epoch 111/10000
# 9/9 [==============================] - 4s 441ms/step - loss: 0.9576 - sparse_categorical_accuracy: 0.5754 - val_loss: 0.9296 - val_sparse_categorical_accuracy: 0.5848
# Epoch 112/10000
# 9/9 [==============================] - 4s 435ms/step - loss: 0.9554 - sparse_categorical_accuracy: 0.5768 - val_loss: 0.9260 - val_sparse_categorical_accuracy: 0.5884
# Epoch 113/10000
# 9/9 [==============================] - 4s 419ms/step - loss: 0.9534 - sparse_categorical_accuracy: 0.5773 - val_loss: 0.9255 - val_sparse_categorical_accuracy: 0.5874
# Epoch 114/10000
# 9/9 [==============================] - 4s 432ms/step - loss: 0.9527 - sparse_categorical_accuracy: 0.5780 - val_loss: 0.9256 - val_sparse_categorical_accuracy: 0.5874
# Epoch 115/10000
# 9/9 [==============================] - 4s 452ms/step - loss: 0.9501 - sparse_categorical_accuracy: 0.5792 - val_loss: 0.9236 - val_sparse_categorical_accuracy: 0.5883
# Epoch 116/10000
# 9/9 [==============================] - 4s 427ms/step - loss: 0.9481 - sparse_categorical_accuracy: 0.5808 - val_loss: 0.9182 - val_sparse_categorical_accuracy: 0.5915
# Epoch 117/10000
# 9/9 [==============================] - 4s 430ms/step - loss: 0.9457 - sparse_categorical_accuracy: 0.5823 - val_loss: 0.9132 - val_sparse_categorical_accuracy: 0.5943
# Epoch 118/10000
# 9/9 [==============================] - 4s 452ms/step - loss: 0.9446 - sparse_categorical_accuracy: 0.5833 - val_loss: 0.9123 - val_sparse_categorical_accuracy: 0.5950
# Epoch 119/10000
# 9/9 [==============================] - 4s 428ms/step - loss: 0.9435 - sparse_categorical_accuracy: 0.5833 - val_loss: 0.9102 - val_sparse_categorical_accuracy: 0.5956
# Epoch 120/10000
# 9/9 [==============================] - 4s 429ms/step - loss: 0.9415 - sparse_categorical_accuracy: 0.5843 - val_loss: 0.9078 - val_sparse_categorical_accuracy: 0.5966
# Epoch 121/10000
# 9/9 [==============================] - 4s 452ms/step - loss: 0.9398 - sparse_categorical_accuracy: 0.5853 - val_loss: 0.9072 - val_sparse_categorical_accuracy: 0.5965
# Epoch 122/10000
# 9/9 [==============================] - 4s 452ms/step - loss: 0.9384 - sparse_categorical_accuracy: 0.5851 - val_loss: 0.9053 - val_sparse_categorical_accuracy: 0.5969
# Epoch 123/10000
# 9/9 [==============================] - 4s 441ms/step - loss: 0.9369 - sparse_categorical_accuracy: 0.5860 - val_loss: 0.9020 - val_sparse_categorical_accuracy: 0.5988
# Epoch 124/10000
# 9/9 [==============================] - 4s 423ms/step - loss: 0.9339 - sparse_categorical_accuracy: 0.5878 - val_loss: 0.8987 - val_sparse_categorical_accuracy: 0.6016
# Epoch 125/10000
# 9/9 [==============================] - 4s 416ms/step - loss: 0.9330 - sparse_categorical_accuracy: 0.5880 - val_loss: 0.8977 - val_sparse_categorical_accuracy: 0.6030
# Epoch 126/10000
# 9/9 [==============================] - 4s 424ms/step - loss: 0.9325 - sparse_categorical_accuracy: 0.5876 - val_loss: 0.8964 - val_sparse_categorical_accuracy: 0.6028
# Epoch 127/10000
# 9/9 [==============================] - 4s 420ms/step - loss: 0.9305 - sparse_categorical_accuracy: 0.5892 - val_loss: 0.8952 - val_sparse_categorical_accuracy: 0.6033
# Epoch 128/10000
# 9/9 [==============================] - 4s 446ms/step - loss: 0.9286 - sparse_categorical_accuracy: 0.5899 - val_loss: 0.8921 - val_sparse_categorical_accuracy: 0.6051
# Epoch 129/10000
# 9/9 [==============================] - 4s 454ms/step - loss: 0.9263 - sparse_categorical_accuracy: 0.5911 - val_loss: 0.8891 - val_sparse_categorical_accuracy: 0.6065
# Epoch 130/10000
# 9/9 [==============================] - 4s 440ms/step - loss: 0.9255 - sparse_categorical_accuracy: 0.5913 - val_loss: 0.8887 - val_sparse_categorical_accuracy: 0.6070
# Epoch 131/10000
# 9/9 [==============================] - 4s 448ms/step - loss: 0.9242 - sparse_categorical_accuracy: 0.5920 - val_loss: 0.8883 - val_sparse_categorical_accuracy: 0.6070
# Epoch 132/10000
# 9/9 [==============================] - 4s 457ms/step - loss: 0.9219 - sparse_categorical_accuracy: 0.5939 - val_loss: 0.8859 - val_sparse_categorical_accuracy: 0.6083
# Epoch 133/10000
# 9/9 [==============================] - 4s 418ms/step - loss: 0.9204 - sparse_categorical_accuracy: 0.5937 - val_loss: 0.8829 - val_sparse_categorical_accuracy: 0.6095
# Epoch 134/10000
# 9/9 [==============================] - 4s 425ms/step - loss: 0.9204 - sparse_categorical_accuracy: 0.5937 - val_loss: 0.8808 - val_sparse_categorical_accuracy: 0.6109
# Epoch 135/10000
# 9/9 [==============================] - 4s 445ms/step - loss: 0.9169 - sparse_categorical_accuracy: 0.5948 - val_loss: 0.8794 - val_sparse_categorical_accuracy: 0.6115
# Epoch 136/10000
# 9/9 [==============================] - 4s 430ms/step - loss: 0.9162 - sparse_categorical_accuracy: 0.5955 - val_loss: 0.8798 - val_sparse_categorical_accuracy: 0.6123
# Epoch 137/10000
# 9/9 [==============================] - 4s 437ms/step - loss: 0.9150 - sparse_categorical_accuracy: 0.5959 - val_loss: 0.8779 - val_sparse_categorical_accuracy: 0.6122
# Epoch 138/10000
# 9/9 [==============================] - 4s 437ms/step - loss: 0.9132 - sparse_categorical_accuracy: 0.5965 - val_loss: 0.8747 - val_sparse_categorical_accuracy: 0.6142
# Epoch 139/10000
# 9/9 [==============================] - 4s 432ms/step - loss: 0.9120 - sparse_categorical_accuracy: 0.5977 - val_loss: 0.8737 - val_sparse_categorical_accuracy: 0.6157
# Epoch 140/10000
# 9/9 [==============================] - 4s 438ms/step - loss: 0.9101 - sparse_categorical_accuracy: 0.5982 - val_loss: 0.8730 - val_sparse_categorical_accuracy: 0.6144
# Epoch 141/10000
# 9/9 [==============================] - 4s 422ms/step - loss: 0.9098 - sparse_categorical_accuracy: 0.5985 - val_loss: 0.8699 - val_sparse_categorical_accuracy: 0.6162
# Epoch 142/10000
# 9/9 [==============================] - 4s 408ms/step - loss: 0.9075 - sparse_categorical_accuracy: 0.5989 - val_loss: 0.8675 - val_sparse_categorical_accuracy: 0.6179
# Epoch 143/10000
# 9/9 [==============================] - 4s 456ms/step - loss: 0.9064 - sparse_categorical_accuracy: 0.5996 - val_loss: 0.8673 - val_sparse_categorical_accuracy: 0.6185
# Epoch 144/10000
# 9/9 [==============================] - 4s 415ms/step - loss: 0.9044 - sparse_categorical_accuracy: 0.6010 - val_loss: 0.8682 - val_sparse_categorical_accuracy: 0.6188
# Epoch 145/10000
# 9/9 [==============================] - 4s 435ms/step - loss: 0.9031 - sparse_categorical_accuracy: 0.6019 - val_loss: 0.8661 - val_sparse_categorical_accuracy: 0.6200
# Epoch 146/10000
# 9/9 [==============================] - 4s 404ms/step - loss: 0.9017 - sparse_categorical_accuracy: 0.6018 - val_loss: 0.8645 - val_sparse_categorical_accuracy: 0.6205
# Epoch 147/10000
# 9/9 [==============================] - 4s 450ms/step - loss: 0.9014 - sparse_categorical_accuracy: 0.6023 - val_loss: 0.8614 - val_sparse_categorical_accuracy: 0.6225
# Epoch 148/10000
# 9/9 [==============================] - 4s 457ms/step - loss: 0.8990 - sparse_categorical_accuracy: 0.6037 - val_loss: 0.8607 - val_sparse_categorical_accuracy: 0.6228
# Epoch 149/10000
# 9/9 [==============================] - 4s 451ms/step - loss: 0.8973 - sparse_categorical_accuracy: 0.6041 - val_loss: 0.8581 - val_sparse_categorical_accuracy: 0.6247
# Epoch 150/10000
# 9/9 [==============================] - 4s 430ms/step - loss: 0.8956 - sparse_categorical_accuracy: 0.6041 - val_loss: 0.8578 - val_sparse_categorical_accuracy: 0.6244
# Epoch 151/10000
# 9/9 [==============================] - 4s 456ms/step - loss: 0.8952 - sparse_categorical_accuracy: 0.6053 - val_loss: 0.8569 - val_sparse_categorical_accuracy: 0.6248
# Epoch 152/10000
# 9/9 [==============================] - 4s 470ms/step - loss: 0.8937 - sparse_categorical_accuracy: 0.6061 - val_loss: 0.8540 - val_sparse_categorical_accuracy: 0.6251
# Epoch 153/10000
# 9/9 [==============================] - 4s 454ms/step - loss: 0.8923 - sparse_categorical_accuracy: 0.6067 - val_loss: 0.8521 - val_sparse_categorical_accuracy: 0.6258
# Epoch 154/10000
# 9/9 [==============================] - 4s 441ms/step - loss: 0.8905 - sparse_categorical_accuracy: 0.6073 - val_loss: 0.8512 - val_sparse_categorical_accuracy: 0.6264
# Epoch 155/10000
# 9/9 [==============================] - 4s 431ms/step - loss: 0.8900 - sparse_categorical_accuracy: 0.6069 - val_loss: 0.8499 - val_sparse_categorical_accuracy: 0.6279
# Epoch 156/10000
# 9/9 [==============================] - 4s 428ms/step - loss: 0.8880 - sparse_categorical_accuracy: 0.6082 - val_loss: 0.8477 - val_sparse_categorical_accuracy: 0.6285
# Epoch 157/10000
# 9/9 [==============================] - 4s 413ms/step - loss: 0.8862 - sparse_categorical_accuracy: 0.6099 - val_loss: 0.8482 - val_sparse_categorical_accuracy: 0.6275
# Epoch 158/10000
# 9/9 [==============================] - 4s 424ms/step - loss: 0.8852 - sparse_categorical_accuracy: 0.6102 - val_loss: 0.8446 - val_sparse_categorical_accuracy: 0.6298
# Epoch 159/10000
# 9/9 [==============================] - 4s 448ms/step - loss: 0.8839 - sparse_categorical_accuracy: 0.6104 - val_loss: 0.8424 - val_sparse_categorical_accuracy: 0.6318
# Epoch 160/10000
# 9/9 [==============================] - 4s 424ms/step - loss: 0.8827 - sparse_categorical_accuracy: 0.6114 - val_loss: 0.8425 - val_sparse_categorical_accuracy: 0.6312
# Epoch 161/10000
# 9/9 [==============================] - 4s 440ms/step - loss: 0.8803 - sparse_categorical_accuracy: 0.6115 - val_loss: 0.8393 - val_sparse_categorical_accuracy: 0.6319
# Epoch 162/10000
# 9/9 [==============================] - 4s 427ms/step - loss: 0.8798 - sparse_categorical_accuracy: 0.6123 - val_loss: 0.8378 - val_sparse_categorical_accuracy: 0.6321
# Epoch 163/10000
# 9/9 [==============================] - 4s 426ms/step - loss: 0.8774 - sparse_categorical_accuracy: 0.6134 - val_loss: 0.8372 - val_sparse_categorical_accuracy: 0.6331
# Epoch 164/10000
# 9/9 [==============================] - 4s 456ms/step - loss: 0.8762 - sparse_categorical_accuracy: 0.6136 - val_loss: 0.8346 - val_sparse_categorical_accuracy: 0.6336
# Epoch 165/10000
# 9/9 [==============================] - 4s 446ms/step - loss: 0.8747 - sparse_categorical_accuracy: 0.6142 - val_loss: 0.8346 - val_sparse_categorical_accuracy: 0.6335
# Epoch 166/10000
# 9/9 [==============================] - 4s 444ms/step - loss: 0.8734 - sparse_categorical_accuracy: 0.6153 - val_loss: 0.8327 - val_sparse_categorical_accuracy: 0.6347
# Epoch 167/10000
# 9/9 [==============================] - 4s 455ms/step - loss: 0.8717 - sparse_categorical_accuracy: 0.6158 - val_loss: 0.8298 - val_sparse_categorical_accuracy: 0.6358
# Epoch 168/10000
# 9/9 [==============================] - 4s 456ms/step - loss: 0.8706 - sparse_categorical_accuracy: 0.6157 - val_loss: 0.8307 - val_sparse_categorical_accuracy: 0.6360
# Epoch 169/10000
# 9/9 [==============================] - 4s 467ms/step - loss: 0.8686 - sparse_categorical_accuracy: 0.6161 - val_loss: 0.8285 - val_sparse_categorical_accuracy: 0.6361
# Epoch 170/10000
# 9/9 [==============================] - 4s 448ms/step - loss: 0.8679 - sparse_categorical_accuracy: 0.6173 - val_loss: 0.8256 - val_sparse_categorical_accuracy: 0.6375
# Epoch 171/10000
# 9/9 [==============================] - 4s 442ms/step - loss: 0.8662 - sparse_categorical_accuracy: 0.6180 - val_loss: 0.8240 - val_sparse_categorical_accuracy: 0.6387
# Epoch 172/10000
# 9/9 [==============================] - 5s 499ms/step - loss: 0.8645 - sparse_categorical_accuracy: 0.6187 - val_loss: 0.8203 - val_sparse_categorical_accuracy: 0.6414
# Epoch 173/10000
# 9/9 [==============================] - 4s 455ms/step - loss: 0.8625 - sparse_categorical_accuracy: 0.6199 - val_loss: 0.8174 - val_sparse_categorical_accuracy: 0.6405
# Epoch 174/10000
# 9/9 [==============================] - 4s 451ms/step - loss: 0.8610 - sparse_categorical_accuracy: 0.6208 - val_loss: 0.8160 - val_sparse_categorical_accuracy: 0.6428
# Epoch 175/10000
# 9/9 [==============================] - 4s 437ms/step - loss: 0.8615 - sparse_categorical_accuracy: 0.6206 - val_loss: 0.8125 - val_sparse_categorical_accuracy: 0.6433
# Epoch 176/10000
# 9/9 [==============================] - 5s 490ms/step - loss: 0.8594 - sparse_categorical_accuracy: 0.6214 - val_loss: 0.8141 - val_sparse_categorical_accuracy: 0.6422
# Epoch 177/10000
# 9/9 [==============================] - 4s 438ms/step - loss: 0.8564 - sparse_categorical_accuracy: 0.6223 - val_loss: 0.8143 - val_sparse_categorical_accuracy: 0.6415
# Epoch 178/10000
# 9/9 [==============================] - 4s 401ms/step - loss: 0.8551 - sparse_categorical_accuracy: 0.6223 - val_loss: 0.8104 - val_sparse_categorical_accuracy: 0.6440
# Epoch 179/10000
# 9/9 [==============================] - 4s 459ms/step - loss: 0.8547 - sparse_categorical_accuracy: 0.6233 - val_loss: 0.8069 - val_sparse_categorical_accuracy: 0.6470
# Epoch 180/10000
# 9/9 [==============================] - 4s 457ms/step - loss: 0.8535 - sparse_categorical_accuracy: 0.6237 - val_loss: 0.8059 - val_sparse_categorical_accuracy: 0.6469
# Epoch 181/10000
# 9/9 [==============================] - 4s 403ms/step - loss: 0.8516 - sparse_categorical_accuracy: 0.6247 - val_loss: 0.8077 - val_sparse_categorical_accuracy: 0.6461
# Epoch 182/10000
# 9/9 [==============================] - 4s 457ms/step - loss: 0.8500 - sparse_categorical_accuracy: 0.6243 - val_loss: 0.8051 - val_sparse_categorical_accuracy: 0.6465
# Epoch 183/10000
# 9/9 [==============================] - 4s 461ms/step - loss: 0.8484 - sparse_categorical_accuracy: 0.6266 - val_loss: 0.8012 - val_sparse_categorical_accuracy: 0.6491
# Epoch 184/10000
# 9/9 [==============================] - 4s 478ms/step - loss: 0.8476 - sparse_categorical_accuracy: 0.6263 - val_loss: 0.8001 - val_sparse_categorical_accuracy: 0.6492
# Epoch 185/10000
# 9/9 [==============================] - 4s 447ms/step - loss: 0.8470 - sparse_categorical_accuracy: 0.6259 - val_loss: 0.8013 - val_sparse_categorical_accuracy: 0.6490
# Epoch 186/10000
# 9/9 [==============================] - 4s 443ms/step - loss: 0.8452 - sparse_categorical_accuracy: 0.6277 - val_loss: 0.7987 - val_sparse_categorical_accuracy: 0.6486
# Epoch 187/10000
# 9/9 [==============================] - 4s 464ms/step - loss: 0.8431 - sparse_categorical_accuracy: 0.6281 - val_loss: 0.7978 - val_sparse_categorical_accuracy: 0.6481
# Epoch 188/10000
# 9/9 [==============================] - 4s 447ms/step - loss: 0.8420 - sparse_categorical_accuracy: 0.6277 - val_loss: 0.7964 - val_sparse_categorical_accuracy: 0.6486
# Epoch 189/10000
# 9/9 [==============================] - 4s 475ms/step - loss: 0.8408 - sparse_categorical_accuracy: 0.6297 - val_loss: 0.7966 - val_sparse_categorical_accuracy: 0.6483
# Epoch 190/10000
# 9/9 [==============================] - 4s 463ms/step - loss: 0.8397 - sparse_categorical_accuracy: 0.6303 - val_loss: 0.7965 - val_sparse_categorical_accuracy: 0.6485
# Epoch 191/10000
# 9/9 [==============================] - 4s 447ms/step - loss: 0.8365 - sparse_categorical_accuracy: 0.6318 - val_loss: 0.7934 - val_sparse_categorical_accuracy: 0.6500
# Epoch 192/10000
# 9/9 [==============================] - 4s 470ms/step - loss: 0.8366 - sparse_categorical_accuracy: 0.6312 - val_loss: 0.7902 - val_sparse_categorical_accuracy: 0.6525
# Epoch 193/10000
# 9/9 [==============================] - 4s 453ms/step - loss: 0.8364 - sparse_categorical_accuracy: 0.6310 - val_loss: 0.7881 - val_sparse_categorical_accuracy: 0.6527
# Epoch 194/10000
# 9/9 [==============================] - 4s 433ms/step - loss: 0.8342 - sparse_categorical_accuracy: 0.6318 - val_loss: 0.7870 - val_sparse_categorical_accuracy: 0.6525
# Epoch 195/10000
# 9/9 [==============================] - 4s 437ms/step - loss: 0.8329 - sparse_categorical_accuracy: 0.6320 - val_loss: 0.7864 - val_sparse_categorical_accuracy: 0.6531
# Epoch 196/10000
# 9/9 [==============================] - 4s 446ms/step - loss: 0.8327 - sparse_categorical_accuracy: 0.6318 - val_loss: 0.7843 - val_sparse_categorical_accuracy: 0.6549
# Epoch 197/10000
# 9/9 [==============================] - 4s 449ms/step - loss: 0.8305 - sparse_categorical_accuracy: 0.6340 - val_loss: 0.7814 - val_sparse_categorical_accuracy: 0.6557
# Epoch 198/10000
# 9/9 [==============================] - 4s 451ms/step - loss: 0.8296 - sparse_categorical_accuracy: 0.6348 - val_loss: 0.7831 - val_sparse_categorical_accuracy: 0.6554
# Epoch 199/10000
# 9/9 [==============================] - 4s 440ms/step - loss: 0.8272 - sparse_categorical_accuracy: 0.6351 - val_loss: 0.7821 - val_sparse_categorical_accuracy: 0.6561
# Epoch 200/10000
# 9/9 [==============================] - 4s 445ms/step - loss: 0.8265 - sparse_categorical_accuracy: 0.6366 - val_loss: 0.7797 - val_sparse_categorical_accuracy: 0.6572
# Epoch 201/10000
# 9/9 [==============================] - 5s 490ms/step - loss: 0.8258 - sparse_categorical_accuracy: 0.6362 - val_loss: 0.7773 - val_sparse_categorical_accuracy: 0.6577
# Epoch 202/10000
# 9/9 [==============================] - 4s 430ms/step - loss: 0.8253 - sparse_categorical_accuracy: 0.6366 - val_loss: 0.7763 - val_sparse_categorical_accuracy: 0.6587
# Epoch 203/10000
# 9/9 [==============================] - 4s 449ms/step - loss: 0.8242 - sparse_categorical_accuracy: 0.6368 - val_loss: 0.7741 - val_sparse_categorical_accuracy: 0.6593
# Epoch 204/10000
# 9/9 [==============================] - 4s 463ms/step - loss: 0.8220 - sparse_categorical_accuracy: 0.6374 - val_loss: 0.7749 - val_sparse_categorical_accuracy: 0.6596
# Epoch 205/10000
# 9/9 [==============================] - 4s 458ms/step - loss: 0.8227 - sparse_categorical_accuracy: 0.6370 - val_loss: 0.7717 - val_sparse_categorical_accuracy: 0.6600
# Epoch 206/10000
# 9/9 [==============================] - 4s 453ms/step - loss: 0.8196 - sparse_categorical_accuracy: 0.6389 - val_loss: 0.7723 - val_sparse_categorical_accuracy: 0.6597
# Epoch 207/10000
# 9/9 [==============================] - 4s 452ms/step - loss: 0.8204 - sparse_categorical_accuracy: 0.6392 - val_loss: 0.7707 - val_sparse_categorical_accuracy: 0.6605
# Epoch 208/10000
# 9/9 [==============================] - 4s 452ms/step - loss: 0.8179 - sparse_categorical_accuracy: 0.6402 - val_loss: 0.7698 - val_sparse_categorical_accuracy: 0.6608
# Epoch 209/10000
# 9/9 [==============================] - 5s 461ms/step - loss: 0.8172 - sparse_categorical_accuracy: 0.6394 - val_loss: 0.7680 - val_sparse_categorical_accuracy: 0.6626
# Epoch 210/10000
# 9/9 [==============================] - 4s 431ms/step - loss: 0.8155 - sparse_categorical_accuracy: 0.6411 - val_loss: 0.7693 - val_sparse_categorical_accuracy: 0.6620
# Epoch 211/10000
# 9/9 [==============================] - 4s 450ms/step - loss: 0.8145 - sparse_categorical_accuracy: 0.6420 - val_loss: 0.7682 - val_sparse_categorical_accuracy: 0.6623
# Epoch 212/10000
# 9/9 [==============================] - 4s 463ms/step - loss: 0.8130 - sparse_categorical_accuracy: 0.6415 - val_loss: 0.7651 - val_sparse_categorical_accuracy: 0.6646
# Epoch 213/10000
# 9/9 [==============================] - 4s 441ms/step - loss: 0.8125 - sparse_categorical_accuracy: 0.6422 - val_loss: 0.7666 - val_sparse_categorical_accuracy: 0.6626
# Epoch 214/10000
# 9/9 [==============================] - 4s 440ms/step - loss: 0.8111 - sparse_categorical_accuracy: 0.6433 - val_loss: 0.7649 - val_sparse_categorical_accuracy: 0.6628
# Epoch 215/10000
# 9/9 [==============================] - 4s 483ms/step - loss: 0.8096 - sparse_categorical_accuracy: 0.6435 - val_loss: 0.7625 - val_sparse_categorical_accuracy: 0.6645
# Epoch 216/10000
# 9/9 [==============================] - 4s 451ms/step - loss: 0.8107 - sparse_categorical_accuracy: 0.6437 - val_loss: 0.7627 - val_sparse_categorical_accuracy: 0.6653
# Epoch 217/10000
# 9/9 [==============================] - 4s 427ms/step - loss: 0.8082 - sparse_categorical_accuracy: 0.6445 - val_loss: 0.7603 - val_sparse_categorical_accuracy: 0.6674
# Epoch 218/10000
# 9/9 [==============================] - 4s 437ms/step - loss: 0.8076 - sparse_categorical_accuracy: 0.6453 - val_loss: 0.7602 - val_sparse_categorical_accuracy: 0.6666
# Epoch 219/10000
# 9/9 [==============================] - 4s 434ms/step - loss: 0.8065 - sparse_categorical_accuracy: 0.6449 - val_loss: 0.7592 - val_sparse_categorical_accuracy: 0.6676
# Epoch 220/10000
# 9/9 [==============================] - 4s 450ms/step - loss: 0.8059 - sparse_categorical_accuracy: 0.6445 - val_loss: 0.7593 - val_sparse_categorical_accuracy: 0.6675
# Epoch 221/10000
# 9/9 [==============================] - 4s 463ms/step - loss: 0.8046 - sparse_categorical_accuracy: 0.6464 - val_loss: 0.7579 - val_sparse_categorical_accuracy: 0.6684
# Epoch 222/10000
# 9/9 [==============================] - 4s 439ms/step - loss: 0.8037 - sparse_categorical_accuracy: 0.6456 - val_loss: 0.7582 - val_sparse_categorical_accuracy: 0.6686
# Epoch 223/10000
# 9/9 [==============================] - 4s 442ms/step - loss: 0.8030 - sparse_categorical_accuracy: 0.6472 - val_loss: 0.7598 - val_sparse_categorical_accuracy: 0.6668
# Epoch 224/10000
# 9/9 [==============================] - 4s 433ms/step - loss: 0.8022 - sparse_categorical_accuracy: 0.6473 - val_loss: 0.7575 - val_sparse_categorical_accuracy: 0.6666
# Epoch 225/10000
# 9/9 [==============================] - 4s 434ms/step - loss: 0.8000 - sparse_categorical_accuracy: 0.6481 - val_loss: 0.7553 - val_sparse_categorical_accuracy: 0.6699
# Epoch 226/10000
# 9/9 [==============================] - 4s 456ms/step - loss: 0.8002 - sparse_categorical_accuracy: 0.6483 - val_loss: 0.7549 - val_sparse_categorical_accuracy: 0.6691
# Epoch 227/10000
# 9/9 [==============================] - 4s 438ms/step - loss: 0.8001 - sparse_categorical_accuracy: 0.6485 - val_loss: 0.7551 - val_sparse_categorical_accuracy: 0.6688
# Epoch 228/10000
# 9/9 [==============================] - 4s 411ms/step - loss: 0.7984 - sparse_categorical_accuracy: 0.6497 - val_loss: 0.7536 - val_sparse_categorical_accuracy: 0.6698
# Epoch 229/10000
# 9/9 [==============================] - 4s 408ms/step - loss: 0.7975 - sparse_categorical_accuracy: 0.6494 - val_loss: 0.7528 - val_sparse_categorical_accuracy: 0.6698
# Epoch 230/10000
# 9/9 [==============================] - 4s 454ms/step - loss: 0.7962 - sparse_categorical_accuracy: 0.6504 - val_loss: 0.7504 - val_sparse_categorical_accuracy: 0.6711
# Epoch 231/10000
# 9/9 [==============================] - 4s 471ms/step - loss: 0.7957 - sparse_categorical_accuracy: 0.6516 - val_loss: 0.7520 - val_sparse_categorical_accuracy: 0.6695
# Epoch 232/10000
# 9/9 [==============================] - 4s 439ms/step - loss: 0.7939 - sparse_categorical_accuracy: 0.6510 - val_loss: 0.7531 - val_sparse_categorical_accuracy: 0.6690
# Epoch 233/10000
# 9/9 [==============================] - 4s 433ms/step - loss: 0.7942 - sparse_categorical_accuracy: 0.6519 - val_loss: 0.7497 - val_sparse_categorical_accuracy: 0.6712
# Epoch 234/10000
# 9/9 [==============================] - 4s 452ms/step - loss: 0.7925 - sparse_categorical_accuracy: 0.6523 - val_loss: 0.7474 - val_sparse_categorical_accuracy: 0.6733
# Epoch 235/10000
# 9/9 [==============================] - 4s 442ms/step - loss: 0.7924 - sparse_categorical_accuracy: 0.6514 - val_loss: 0.7467 - val_sparse_categorical_accuracy: 0.6731
# Epoch 236/10000
# 9/9 [==============================] - 4s 450ms/step - loss: 0.7912 - sparse_categorical_accuracy: 0.6522 - val_loss: 0.7474 - val_sparse_categorical_accuracy: 0.6717
# Epoch 237/10000
# 9/9 [==============================] - 4s 446ms/step - loss: 0.7902 - sparse_categorical_accuracy: 0.6525 - val_loss: 0.7461 - val_sparse_categorical_accuracy: 0.6734
# Epoch 238/10000
# 9/9 [==============================] - 4s 448ms/step - loss: 0.7892 - sparse_categorical_accuracy: 0.6546 - val_loss: 0.7449 - val_sparse_categorical_accuracy: 0.6738
# Epoch 239/10000
# 9/9 [==============================] - 4s 456ms/step - loss: 0.7892 - sparse_categorical_accuracy: 0.6537 - val_loss: 0.7475 - val_sparse_categorical_accuracy: 0.6716
# Epoch 240/10000
# 9/9 [==============================] - 4s 432ms/step - loss: 0.7885 - sparse_categorical_accuracy: 0.6535 - val_loss: 0.7477 - val_sparse_categorical_accuracy: 0.6717
# Epoch 241/10000
# 9/9 [==============================] - 4s 431ms/step - loss: 0.7861 - sparse_categorical_accuracy: 0.6547 - val_loss: 0.7461 - val_sparse_categorical_accuracy: 0.6717
# Epoch 242/10000
# 9/9 [==============================] - 4s 444ms/step - loss: 0.7867 - sparse_categorical_accuracy: 0.6540 - val_loss: 0.7458 - val_sparse_categorical_accuracy: 0.6725
# Epoch 243/10000
# 9/9 [==============================] - 4s 431ms/step - loss: 0.7854 - sparse_categorical_accuracy: 0.6559 - val_loss: 0.7478 - val_sparse_categorical_accuracy: 0.6717
# Epoch 244/10000
# 9/9 [==============================] - 4s 426ms/step - loss: 0.7853 - sparse_categorical_accuracy: 0.6551 - val_loss: 0.7444 - val_sparse_categorical_accuracy: 0.6732
# Epoch 245/10000
# 9/9 [==============================] - 4s 465ms/step - loss: 0.7832 - sparse_categorical_accuracy: 0.6558 - val_loss: 0.7458 - val_sparse_categorical_accuracy: 0.6724
# Epoch 246/10000
# 9/9 [==============================] - 4s 432ms/step - loss: 0.7832 - sparse_categorical_accuracy: 0.6563 - val_loss: 0.7441 - val_sparse_categorical_accuracy: 0.6731
# Epoch 247/10000
# 9/9 [==============================] - 4s 466ms/step - loss: 0.7826 - sparse_categorical_accuracy: 0.6570 - val_loss: 0.7423 - val_sparse_categorical_accuracy: 0.6742
# Epoch 248/10000
# 9/9 [==============================] - 4s 427ms/step - loss: 0.7808 - sparse_categorical_accuracy: 0.6583 - val_loss: 0.7419 - val_sparse_categorical_accuracy: 0.6737
# Epoch 249/10000
# 9/9 [==============================] - 4s 424ms/step - loss: 0.7808 - sparse_categorical_accuracy: 0.6577 - val_loss: 0.7422 - val_sparse_categorical_accuracy: 0.6739
# Epoch 250/10000
# 9/9 [==============================] - 4s 450ms/step - loss: 0.7798 - sparse_categorical_accuracy: 0.6578 - val_loss: 0.7396 - val_sparse_categorical_accuracy: 0.6759
# Epoch 251/10000
# 9/9 [==============================] - 4s 448ms/step - loss: 0.7783 - sparse_categorical_accuracy: 0.6589 - val_loss: 0.7407 - val_sparse_categorical_accuracy: 0.6753
# Epoch 252/10000
# 9/9 [==============================] - 4s 483ms/step - loss: 0.7792 - sparse_categorical_accuracy: 0.6582 - val_loss: 0.7393 - val_sparse_categorical_accuracy: 0.6766
# Epoch 253/10000
# 9/9 [==============================] - 4s 465ms/step - loss: 0.7780 - sparse_categorical_accuracy: 0.6588 - val_loss: 0.7363 - val_sparse_categorical_accuracy: 0.6774
# Epoch 254/10000
# 9/9 [==============================] - 4s 435ms/step - loss: 0.7769 - sparse_categorical_accuracy: 0.6588 - val_loss: 0.7373 - val_sparse_categorical_accuracy: 0.6772
# Epoch 255/10000
# 9/9 [==============================] - 4s 430ms/step - loss: 0.7751 - sparse_categorical_accuracy: 0.6600 - val_loss: 0.7380 - val_sparse_categorical_accuracy: 0.6769
# Epoch 256/10000
# 9/9 [==============================] - 4s 460ms/step - loss: 0.7747 - sparse_categorical_accuracy: 0.6607 - val_loss: 0.7357 - val_sparse_categorical_accuracy: 0.6779
# Epoch 257/10000
# 9/9 [==============================] - 4s 477ms/step - loss: 0.7749 - sparse_categorical_accuracy: 0.6608 - val_loss: 0.7357 - val_sparse_categorical_accuracy: 0.6779
# Epoch 258/10000
# 9/9 [==============================] - 4s 436ms/step - loss: 0.7740 - sparse_categorical_accuracy: 0.6609 - val_loss: 0.7356 - val_sparse_categorical_accuracy: 0.6783
# Epoch 259/10000
# 9/9 [==============================] - 4s 435ms/step - loss: 0.7731 - sparse_categorical_accuracy: 0.6606 - val_loss: 0.7330 - val_sparse_categorical_accuracy: 0.6795
# Epoch 260/10000
# 9/9 [==============================] - 4s 425ms/step - loss: 0.7724 - sparse_categorical_accuracy: 0.6605 - val_loss: 0.7351 - val_sparse_categorical_accuracy: 0.6788
# Epoch 261/10000
# 9/9 [==============================] - 4s 431ms/step - loss: 0.7706 - sparse_categorical_accuracy: 0.6629 - val_loss: 0.7331 - val_sparse_categorical_accuracy: 0.6787
# Epoch 262/10000
# 9/9 [==============================] - 4s 438ms/step - loss: 0.7702 - sparse_categorical_accuracy: 0.6625 - val_loss: 0.7331 - val_sparse_categorical_accuracy: 0.6790
# Epoch 263/10000
# ...
# 9/9 [==============================] - 4s 430ms/step - loss: 0.5845 - sparse_categorical_accuracy: 0.7543 - val_loss: 0.6622 - val_sparse_categorical_accuracy: 0.7244
# Epoch 1144/10000
# 9/9 [==============================] - 4s 436ms/step - loss: 0.5853 - sparse_categorical_accuracy: 0.7545 - val_loss: 0.6619 - val_sparse_categorical_accuracy: 0.7261
# Epoch 1145/10000
# 9/9 [==============================] - 4s 438ms/step - loss: 0.5851 - sparse_categorical_accuracy: 0.7549 - val_loss: 0.6617 - val_sparse_categorical_accuracy: 0.7254
# Epoch 1146/10000
# 9/9 [==============================] - 4s 430ms/step - loss: 0.5847 - sparse_categorical_accuracy: 0.7544 - val_loss: 0.6618 - val_sparse_categorical_accuracy: 0.7259
# Epoch 1147/10000
# 9/9 [==============================] - 4s 419ms/step - loss: 0.5838 - sparse_categorical_accuracy: 0.7553 - val_loss: 0.6629 - val_sparse_categorical_accuracy: 0.7246
# Epoch 1148/10000
# 9/9 [==============================] - 4s 431ms/step - loss: 0.5828 - sparse_categorical_accuracy: 0.7556 - val_loss: 0.6610 - val_sparse_categorical_accuracy: 0.7254
# Epoch 1149/10000
# 9/9 [==============================] - 4s 409ms/step - loss: 0.5844 - sparse_categorical_accuracy: 0.7552 - val_loss: 0.6643 - val_sparse_categorical_accuracy: 0.7244
# Epoch 1150/10000
# 9/9 [==============================] - 4s 420ms/step - loss: 0.5843 - sparse_categorical_accuracy: 0.7553 - val_loss: 0.6640 - val_sparse_categorical_accuracy: 0.7236
# Epoch 1151/10000
# 9/9 [==============================] - 4s 467ms/step - loss: 0.5832 - sparse_categorical_accuracy: 0.7550 - val_loss: 0.6619 - val_sparse_categorical_accuracy: 0.7241
# Epoch 1152/10000
# 9/9 [==============================] - 4s 429ms/step - loss: 0.5820 - sparse_categorical_accuracy: 0.7565 - val_loss: 0.6616 - val_sparse_categorical_accuracy: 0.7244
# Epoch 1153/10000
# 9/9 [==============================] - 4s 443ms/step - loss: 0.5827 - sparse_categorical_accuracy: 0.7555 - val_loss: 0.6640 - val_sparse_categorical_accuracy: 0.7247
# Epoch 1154/10000
# 9/9 [==============================] - 4s 406ms/step - loss: 0.5830 - sparse_categorical_accuracy: 0.7556 - val_loss: 0.6636 - val_sparse_categorical_accuracy: 0.7238
# Epoch 1155/10000
# 9/9 [==============================] - 4s 428ms/step - loss: 0.5834 - sparse_categorical_accuracy: 0.7550 - val_loss: 0.6626 - val_sparse_categorical_accuracy: 0.7236
# Epoch 1156/10000
# 9/9 [==============================] - 4s 400ms/step - loss: 0.5836 - sparse_categorical_accuracy: 0.7553 - val_loss: 0.6617 - val_sparse_categorical_accuracy: 0.7246
# Epoch 1157/10000
# 9/9 [==============================] - 4s 427ms/step - loss: 0.5840 - sparse_categorical_accuracy: 0.7545 - val_loss: 0.6628 - val_sparse_categorical_accuracy: 0.7259
# Epoch 1158/10000
# 9/9 [==============================] - 4s 456ms/step - loss: 0.5829 - sparse_categorical_accuracy: 0.7563 - val_loss: 0.6615 - val_sparse_categorical_accuracy: 0.7256
# Epoch 1159/10000
# 9/9 [==============================] - 4s 411ms/step - loss: 0.5829 - sparse_categorical_accuracy: 0.7555 - val_loss: 0.6618 - val_sparse_categorical_accuracy: 0.7255
# Epoch 1160/10000
# 9/9 [==============================] - 4s 458ms/step - loss: 0.5835 - sparse_categorical_accuracy: 0.7556 - val_loss: 0.6625 - val_sparse_categorical_accuracy: 0.7255
# Epoch 1161/10000
# 9/9 [==============================] - 4s 450ms/step - loss: 0.5821 - sparse_categorical_accuracy: 0.7559 - val_loss: 0.6617 - val_sparse_categorical_accuracy: 0.7257
# Epoch 1162/10000
# 9/9 [==============================] - 4s 420ms/step - loss: 0.5820 - sparse_categorical_accuracy: 0.7556 - val_loss: 0.6620 - val_sparse_categorical_accuracy: 0.7258
# Epoch 1163/10000
# 9/9 [==============================] - 4s 485ms/step - loss: 0.5832 - sparse_categorical_accuracy: 0.7547 - val_loss: 0.6609 - val_sparse_categorical_accuracy: 0.7264
# Epoch 1164/10000
# 9/9 [==============================] - 4s 454ms/step - loss: 0.5821 - sparse_categorical_accuracy: 0.7561 - val_loss: 0.6620 - val_sparse_categorical_accuracy: 0.7243
# Epoch 1165/10000
# 9/9 [==============================] - 4s 420ms/step - loss: 0.5819 - sparse_categorical_accuracy: 0.7558 - val_loss: 0.6638 - val_sparse_categorical_accuracy: 0.7244
# Epoch 1166/10000
# 9/9 [==============================] - 4s 466ms/step - loss: 0.5833 - sparse_categorical_accuracy: 0.7559 - val_loss: 0.6629 - val_sparse_categorical_accuracy: 0.7255
# Epoch 1167/10000
# 9/9 [==============================] - 4s 432ms/step - loss: 0.5814 - sparse_categorical_accuracy: 0.7558 - val_loss: 0.6633 - val_sparse_categorical_accuracy: 0.7248
# Epoch 1168/10000
# 9/9 [==============================] - 4s 415ms/step - loss: 0.5819 - sparse_categorical_accuracy: 0.7554 - val_loss: 0.6622 - val_sparse_categorical_accuracy: 0.7255
# Epoch 1169/10000
# 9/9 [==============================] - 4s 458ms/step - loss: 0.5818 - sparse_categorical_accuracy: 0.7558 - val_loss: 0.6621 - val_sparse_categorical_accuracy: 0.7252
# Epoch 1170/10000
# 9/9 [==============================] - 4s 424ms/step - loss: 0.5825 - sparse_categorical_accuracy: 0.7563 - val_loss: 0.6622 - val_sparse_categorical_accuracy: 0.7253
# Epoch 1171/10000
# 9/9 [==============================] - 4s 450ms/step - loss: 0.5818 - sparse_categorical_accuracy: 0.7563 - val_loss: 0.6624 - val_sparse_categorical_accuracy: 0.7256
# Epoch 1172/10000
# 9/9 [==============================] - 4s 420ms/step - loss: 0.5820 - sparse_categorical_accuracy: 0.7566 - val_loss: 0.6626 - val_sparse_categorical_accuracy: 0.7256
# Epoch 1173/10000
# 9/9 [==============================] - 4s 440ms/step - loss: 0.5819 - sparse_categorical_accuracy: 0.7559 - val_loss: 0.6636 - val_sparse_categorical_accuracy: 0.7249
# Epoch 1174/10000
# 9/9 [==============================] - 4s 446ms/step - loss: 0.5819 - sparse_categorical_accuracy: 0.7560 - val_loss: 0.6629 - val_sparse_categorical_accuracy: 0.7257
# Epoch 1175/10000
# 9/9 [==============================] - 4s 447ms/step - loss: 0.5812 - sparse_categorical_accuracy: 0.7571 - val_loss: 0.6628 - val_sparse_categorical_accuracy: 0.7266
# Epoch 1176/10000
# 9/9 [==============================] - 4s 417ms/step - loss: 0.5813 - sparse_categorical_accuracy: 0.7562 - val_loss: 0.6625 - val_sparse_categorical_accuracy: 0.7251
# Epoch 1177/10000
# 9/9 [==============================] - 4s 415ms/step - loss: 0.5810 - sparse_categorical_accuracy: 0.7565 - val_loss: 0.6634 - val_sparse_categorical_accuracy: 0.7242
# Epoch 1178/10000
# 9/9 [==============================] - 4s 458ms/step - loss: 0.5813 - sparse_categorical_accuracy: 0.7565 - val_loss: 0.6632 - val_sparse_categorical_accuracy: 0.7242
# Epoch 1179/10000
# 9/9 [==============================] - 4s 405ms/step - loss: 0.5818 - sparse_categorical_accuracy: 0.7561 - val_loss: 0.6639 - val_sparse_categorical_accuracy: 0.7231
# Epoch 1180/10000
# 9/9 [==============================] - 4s 437ms/step - loss: 0.5803 - sparse_categorical_accuracy: 0.7569 - val_loss: 0.6649 - val_sparse_categorical_accuracy: 0.7235
# Epoch 1181/10000
# 9/9 [==============================] - 4s 421ms/step - loss: 0.5802 - sparse_categorical_accuracy: 0.7570 - val_loss: 0.6643 - val_sparse_categorical_accuracy: 0.7232
# Epoch 1182/10000
# 9/9 [==============================] - 4s 436ms/step - loss: 0.5805 - sparse_categorical_accuracy: 0.7574 - val_loss: 0.6634 - val_sparse_categorical_accuracy: 0.7236
# Epoch 1183/10000
# 9/9 [==============================] - 4s 428ms/step - loss: 0.5799 - sparse_categorical_accuracy: 0.7571 - val_loss: 0.6648 - val_sparse_categorical_accuracy: 0.7226
# Epoch 1184/10000
# 9/9 [==============================] - 4s 454ms/step - loss: 0.5804 - sparse_categorical_accuracy: 0.7569 - val_loss: 0.6639 - val_sparse_categorical_accuracy: 0.7239
# Epoch 1185/10000
# 9/9 [==============================] - 4s 441ms/step - loss: 0.5809 - sparse_categorical_accuracy: 0.7566 - val_loss: 0.6631 - val_sparse_categorical_accuracy: 0.7245
# Epoch 1186/10000
# 9/9 [==============================] - 4s 455ms/step - loss: 0.5802 - sparse_categorical_accuracy: 0.7566 - val_loss: 0.6650 - val_sparse_categorical_accuracy: 0.7229
# Epoch 1187/10000
# 9/9 [==============================] - 4s 416ms/step - loss: 0.5804 - sparse_categorical_accuracy: 0.7565 - val_loss: 0.6629 - val_sparse_categorical_accuracy: 0.7233
# Epoch 1188/10000
# 9/9 [==============================] - 4s 406ms/step - loss: 0.5804 - sparse_categorical_accuracy: 0.7563 - val_loss: 0.6627 - val_sparse_categorical_accuracy: 0.7246
# Epoch 1189/10000
# 9/9 [==============================] - 4s 449ms/step - loss: 0.5792 - sparse_categorical_accuracy: 0.7573 - val_loss: 0.6612 - val_sparse_categorical_accuracy: 0.7250
# Epoch 1190/10000
# 9/9 [==============================] - 4s 436ms/step - loss: 0.5797 - sparse_categorical_accuracy: 0.7571 - val_loss: 0.6629 - val_sparse_categorical_accuracy: 0.7243
# Epoch 1191/10000
# 9/9 [==============================] - 4s 413ms/step - loss: 0.5801 - sparse_categorical_accuracy: 0.7573 - val_loss: 0.6619 - val_sparse_categorical_accuracy: 0.7261
# Epoch 1192/10000
# 9/9 [==============================] - 4s 422ms/step - loss: 0.5796 - sparse_categorical_accuracy: 0.7568 - val_loss: 0.6629 - val_sparse_categorical_accuracy: 0.7259
# Epoch 1193/10000
# 9/9 [==============================] - 4s 434ms/step - loss: 0.5790 - sparse_categorical_accuracy: 0.7576 - val_loss: 0.6640 - val_sparse_categorical_accuracy: 0.7248
# Epoch 1194/10000
# 9/9 [==============================] - 4s 418ms/step - loss: 0.5797 - sparse_categorical_accuracy: 0.7571 - val_loss: 0.6630 - val_sparse_categorical_accuracy: 0.7244
# Epoch 1195/10000
# 9/9 [==============================] - 4s 437ms/step - loss: 0.5794 - sparse_categorical_accuracy: 0.7569 - val_loss: 0.6624 - val_sparse_categorical_accuracy: 0.7254
# Epoch 1196/10000
# 9/9 [==============================] - 4s 445ms/step - loss: 0.5793 - sparse_categorical_accuracy: 0.7568 - val_loss: 0.6620 - val_sparse_categorical_accuracy: 0.7261
# Epoch 1197/10000
# 9/9 [==============================] - 4s 426ms/step - loss: 0.5799 - sparse_categorical_accuracy: 0.7568 - val_loss: 0.6638 - val_sparse_categorical_accuracy: 0.7248
# Epoch 1198/10000
# 9/9 [==============================] - 4s 444ms/step - loss: 0.5795 - sparse_categorical_accuracy: 0.7573 - val_loss: 0.6623 - val_sparse_categorical_accuracy: 0.7259
# Epoch 1199/10000
# 9/9 [==============================] - 4s 425ms/step - loss: 0.5790 - sparse_categorical_accuracy: 0.7575 - val_loss: 0.6650 - val_sparse_categorical_accuracy: 0.7241
# Epoch 1200/10000
# 9/9 [==============================] - 4s 444ms/step - loss: 0.5795 - sparse_categorical_accuracy: 0.7567 - val_loss: 0.6631 - val_sparse_categorical_accuracy: 0.7248
# Epoch 1201/10000
# 9/9 [==============================] - 4s 439ms/step - loss: 0.5789 - sparse_categorical_accuracy: 0.7576 - val_loss: 0.6637 - val_sparse_categorical_accuracy: 0.7233
# Epoch 1202/10000
# 9/9 [==============================] - 4s 420ms/step - loss: 0.5790 - sparse_categorical_accuracy: 0.7575 - val_loss: 0.6614 - val_sparse_categorical_accuracy: 0.7253
# Epoch 1203/10000
# 9/9 [==============================] - 4s 437ms/step - loss: 0.5791 - sparse_categorical_accuracy: 0.7572 - val_loss: 0.6629 - val_sparse_categorical_accuracy: 0.7259
# Epoch 1204/10000
# 9/9 [==============================] - 4s 428ms/step - loss: 0.5786 - sparse_categorical_accuracy: 0.7575 - val_loss: 0.6625 - val_sparse_categorical_accuracy: 0.7257
# Epoch 1205/10000
# 9/9 [==============================] - 4s 430ms/step - loss: 0.5793 - sparse_categorical_accuracy: 0.7574 - val_loss: 0.6635 - val_sparse_categorical_accuracy: 0.7252
# Epoch 1206/10000
# 9/9 [==============================] - 4s 419ms/step - loss: 0.5773 - sparse_categorical_accuracy: 0.7587 - val_loss: 0.6641 - val_sparse_categorical_accuracy: 0.7245
# Epoch 1207/10000
# 9/9 [==============================] - 4s 436ms/step - loss: 0.5784 - sparse_categorical_accuracy: 0.7575 - val_loss: 0.6631 - val_sparse_categorical_accuracy: 0.7242
# Epoch 1208/10000
# 9/9 [==============================] - 4s 443ms/step - loss: 0.5777 - sparse_categorical_accuracy: 0.7581 - val_loss: 0.6639 - val_sparse_categorical_accuracy: 0.7246
# Epoch 1209/10000
# 9/9 [==============================] - 4s 463ms/step - loss: 0.5778 - sparse_categorical_accuracy: 0.7577 - val_loss: 0.6634 - val_sparse_categorical_accuracy: 0.7257
# Epoch 1210/10000
# 9/9 [==============================] - 4s 470ms/step - loss: 0.5781 - sparse_categorical_accuracy: 0.7580 - val_loss: 0.6625 - val_sparse_categorical_accuracy: 0.7253
# Epoch 1211/10000
# 9/9 [==============================] - 4s 444ms/step - loss: 0.5769 - sparse_categorical_accuracy: 0.7577 - val_loss: 0.6633 - val_sparse_categorical_accuracy: 0.7245
# Epoch 1212/10000
# 9/9 [==============================] - 4s 432ms/step - loss: 0.5784 - sparse_categorical_accuracy: 0.7577 - val_loss: 0.6619 - val_sparse_categorical_accuracy: 0.7238
# Epoch 1213/10000
# 9/9 [==============================] - 4s 444ms/step - loss: 0.5781 - sparse_categorical_accuracy: 0.7574 - val_loss: 0.6629 - val_sparse_categorical_accuracy: 0.7263
# Epoch 1214/10000
# 9/9 [==============================] - 4s 449ms/step - loss: 0.5780 - sparse_categorical_accuracy: 0.7574 - val_loss: 0.6630 - val_sparse_categorical_accuracy: 0.7253
# Epoch 1215/10000
# 9/9 [==============================] - 4s 409ms/step - loss: 0.5774 - sparse_categorical_accuracy: 0.7572 - val_loss: 0.6635 - val_sparse_categorical_accuracy: 0.7250
# Epoch 1216/10000
# 9/9 [==============================] - 4s 435ms/step - loss: 0.5769 - sparse_categorical_accuracy: 0.7585 - val_loss: 0.6628 - val_sparse_categorical_accuracy: 0.7254
# Epoch 1217/10000
# 9/9 [==============================] - 4s 423ms/step - loss: 0.5785 - sparse_categorical_accuracy: 0.7573 - val_loss: 0.6636 - val_sparse_categorical_accuracy: 0.7246
# Epoch 1218/10000
# 9/9 [==============================] - 4s 459ms/step - loss: 0.5772 - sparse_categorical_accuracy: 0.7585 - val_loss: 0.6623 - val_sparse_categorical_accuracy: 0.7267
# Epoch 1219/10000
# 9/9 [==============================] - 4s 443ms/step - loss: 0.5772 - sparse_categorical_accuracy: 0.7583 - val_loss: 0.6629 - val_sparse_categorical_accuracy: 0.7256
# Epoch 1220/10000
# 9/9 [==============================] - 4s 422ms/step - loss: 0.5767 - sparse_categorical_accuracy: 0.7590 - val_loss: 0.6638 - val_sparse_categorical_accuracy: 0.7249
# Epoch 1221/10000
# 9/9 [==============================] - 4s 404ms/step - loss: 0.5768 - sparse_categorical_accuracy: 0.7586 - val_loss: 0.6653 - val_sparse_categorical_accuracy: 0.7233
# Epoch 1222/10000
# 9/9 [==============================] - 4s 438ms/step - loss: 0.5766 - sparse_categorical_accuracy: 0.7587 - val_loss: 0.6631 - val_sparse_categorical_accuracy: 0.7264
# Epoch 1223/10000
# 9/9 [==============================] - 4s 452ms/step - loss: 0.5757 - sparse_categorical_accuracy: 0.7589 - val_loss: 0.6652 - val_sparse_categorical_accuracy: 0.7250
# Epoch 1224/10000
# 9/9 [==============================] - 4s 462ms/step - loss: 0.5767 - sparse_categorical_accuracy: 0.7585 - val_loss: 0.6643 - val_sparse_categorical_accuracy: 0.7257
# Epoch 1225/10000
# 9/9 [==============================] - 4s 429ms/step - loss: 0.5754 - sparse_categorical_accuracy: 0.7595 - val_loss: 0.6632 - val_sparse_categorical_accuracy: 0.7247
# Epoch 1226/10000
# 9/9 [==============================] - 4s 423ms/step - loss: 0.5768 - sparse_categorical_accuracy: 0.7586 - val_loss: 0.6635 - val_sparse_categorical_accuracy: 0.7249
# Epoch 1227/10000
# 9/9 [==============================] - 4s 439ms/step - loss: 0.5773 - sparse_categorical_accuracy: 0.7577 - val_loss: 0.6638 - val_sparse_categorical_accuracy: 0.7265
# Epoch 1228/10000
# 9/9 [==============================] - 4s 449ms/step - loss: 0.5760 - sparse_categorical_accuracy: 0.7588 - val_loss: 0.6632 - val_sparse_categorical_accuracy: 0.7260
# Epoch 1229/10000
# 9/9 [==============================] - 4s 436ms/step - loss: 0.5758 - sparse_categorical_accuracy: 0.7585 - val_loss: 0.6624 - val_sparse_categorical_accuracy: 0.7253

# %%
full_NN_model.save_weights('./save/weights_full_NN_model_val_0f')

full_NN_model = FullNNModel(input_terrain_shape,input_sequence_shape)
full_NN_model.load_weights('./save/weights_full_NN_model_val_0f')
# Out:
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  model_dense_16 (Sequential)  (None, 16)               402768
#
#  dense_142 (Dense)           (None, 6)                 102
#
# =================================================================
# Total params: 402,870
# Trainable params: 401,014
# Non-trainable params: 1,856
# _________________________________________________________________

# %% [markdown]
# #### Prediction and error plot

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'sparse_categorical_accuracy'])

# %%
utils.plot_and_save_history(history,"./results/history_full_NN_model_val_0f.png")

pred_y = full_NN_model.predict(train_dataset)
pred_y = np.argmax(pred_y,axis=-1)

utils.plot_and_save_confusion_matrix(pred_y,new_train_y,"./results/confusion_matrix_full_NN_model.png")
# Out:
# 9/9 [==============================] - 1s 68ms/step

# %% [markdown]
# ### Send predictions

# %%
test_dataset_x = tf.data.Dataset.from_tensor_slices((test_terrain_x,test_sequence_x))
dummy_test_y = np.zeros((test_terrain_x.shape[0],1))
test_dataset_y = tf.data.Dataset.from_tensor_slices(dummy_test_y)
test_dataset = tf.data.Dataset.zip((test_dataset_x, test_dataset_y))

test_dataset = configure_for_performance(test_dataset, config["BATCH_SIZE"])

pred_y = full_NN_model.predict(test_dataset)
pred_y = np.argmax(pred_y,axis=-1)
print("prediction on test set shape :", pred_y.shape)
print(pred_y)


######## Save results to submission file ########
print("--- save ---")
pred_df = pd.DataFrame(pred_y, columns=['change_type'])
pred_df.to_csv("my_submission_full_NN.csv", index=True, index_label='Id')
# Out:
# 4/4 [==============================] - 1s 125ms/step
# prediction on test set shape : (120526,)
# [2 3 2 ... 3 2 2]
# --- save ---
